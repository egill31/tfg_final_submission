# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, confusion_matrix
import itertools
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.transforms as transforms

from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader

from sklearn import metrics
from sklearn.model_selection import train_test_split

import os

import datetime

import seaborn as sns
from tqdm.notebook import tqdm
torch.manual_seed(17)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dir_path = "/content/drive/MyDrive/COVID-19_Radiography_Dataset"
batchnorm_chkpt_path = "/content/drive/MyDrive/COVID-19_Radiography_Dataset/batchnorm"
train_path = "/content/drive/MyDrive/COVID-19_Radiography_Dataset/split_images/train"
val_path = "/content/drive/MyDrive/COVID-19_Radiography_Dataset/split_images/val"
test_path = "/content/drive/MyDrive/COVID-19_Radiography_Dataset/split_images/test"

# %% [markdown]
# # Data Prep

# %%
image_transforms = {
    "train": transforms.Compose([
        transforms.Resize((299, 299)),
        transforms.ToTensor(),
        transforms.RandomGrayscale(p=0.05),
        #transforms.RandomHorizontalFlip(p=0.1), 
        transforms.RandomVerticalFlip(p=0.08),
        transforms.RandomRotation(10),
        #transforms.RandomPerspective(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ]),
    "val": transforms.Compose([
        transforms.Resize((299, 299)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ]),
    "test": transforms.Compose([
        transforms.Resize((299, 299)),
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ])
}


train_dataset = datasets.ImageFolder(
                              root = train_path,
                              transform = image_transforms["train"]
                       )

val_dataset = datasets.ImageFolder(
                              root = val_path,
                              transform = image_transforms["val"]
                       )

test_dataset = datasets.ImageFolder(
                              root = test_path,
                              transform = image_transforms["test"]
                       )

print("Training length: ", len(train_dataset))
print("Validation length: ", len(val_dataset))
print("Testing length: ", len(test_dataset))

dataloader_train = torch.utils.data.DataLoader(train_dataset, batch_size=124, shuffle=True)
dataloader_valid = torch.utils.data.DataLoader(val_dataset, batch_size=124, shuffle=True)
dataloader_test = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=True)
# Out:
# Training length:  11964
# Validation length:  2279
# Testing length:  910

# %% [markdown]
# # Eval functions

# %%
# Functions to create confusion matrix

def get_confusion_tensor(preds, targets):
  stacked = torch.stack(
      (
          torch.cat(targets, dim=0)
          ,torch.cat(preds, dim=0)
      )
      ,dim=1
  )
  cmt = torch.zeros(3,3, dtype=torch.int64)
  for p in stacked:
      tl, pl = p.tolist()
      cmt[int(tl), int(pl)] = cmt[int(tl), int(pl)] + 1
  return cmt

def plot_confusion_matrix(preds, targets, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
  cm = get_confusion_tensor(preds, targets)

  print(cm)
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45, fontsize='large')
  plt.yticks(tick_marks, classes, fontsize='large')

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", fontsize='large', color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')

# %% [markdown]
# # Model

# %%
#torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0, 
#                 dilation=1, groups=1, bias=True, padding_mode='zeros')

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 10)
        self.conv3 = nn.Conv2d(64, 128, 20)
        self.fc1 = nn.Linear(128*25*25, 120)
        self.fc2 = nn.Linear(120, 3)
        self.batchNorm1 = nn.BatchNorm2d(32, momentum=0.04)
        self.batchNorm2 = nn.BatchNorm2d(64, momentum=0.06)
        self.batchNorm3 = nn.BatchNorm2d(128, momentum=0.06)

    def forward(self, x):
      #print("Start: ",x.shape)
      x = self.batchNorm1(self.conv1(x))
      #print("conv1: ",x.shape)
      x = self.pool(F.relu(x))
      #print("first pool: ",x.shape)
      x= self.batchNorm2(self.conv2(x))
      #print("conv2: ", x.shape)
      x = self.pool(F.relu(x))
      #print("second pool: ",x.shape)
      x= self.batchNorm3(self.conv3(x))
      #print("conv3: ", x.shape)
      x = self.pool(F.relu(x))
      #print("second pool: ",x.shape)
      x = x.view(x.size(0), -1)
      #print("x.view: ", x.shape)
      #x = x.view(-1, 16 * 5 * 5)
      x = self.fc1(x)
      #print("FC1 ", x.shape)
      x = F.relu(x)
      #print("relu fc1: ", x.shape)
      x = self.fc2(x)
      #print("FC2 ", x.shape)
      x = F.relu(x)
      #print("relu fc2: ", x.shape)
      return x

# %% [markdown]
# # Training Function

# %%
def train_model(n_epochs, print_every):
  

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)    

  valid_loss_min = np.Inf
  loss_history=[]  
  correct_history=[]  
  val_loss_history=[]  
  val_correct_history=[]  
  val_loss = []
  val_acc = []
  train_loss = []
  train_acc = []
  total_step = len(dataloader_train)
  for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(dataloader_train):
      net.train()
      data_, target_ = data_.to(device), target_.to(device)
      optimizer.zero_grad()
      
      outputs = net(data_)
      loss = criterion(outputs, target_)
      loss.backward()
      optimizer.step()

      running_loss += loss.item()
      _,pred = torch.max(outputs, dim=1)
      correct += torch.sum(pred==target_).item()
      total += target_.size(0)
      if (batch_idx) % print_every == 0:
          print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
      net.eval()
      for data_t, target_t in (dataloader_valid):
        data_t, target_t = data_t.to(device), target_t.to(device)
        outputs_t = net(data_t)
        loss_t = criterion(outputs_t, target_t)
        batch_loss += loss_t.item()
        _,pred_t = torch.max(outputs_t, dim=1)
        correct_t += torch.sum(pred_t==target_t).item()
        total_t += target_t.size(0)
      val_acc.append(100 * correct_t/total_t)
      val_loss.append(batch_loss/len(dataloader_valid))
      network_learned = batch_loss < valid_loss_min
      print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
      if network_learned:
        valid_loss_min = batch_loss
        torch.save(net.state_dict(), batchnorm_chkpt_path+'/'+str(n_epochs)+'_batchNorm.pt')
        print('Improvement-Detected, save-model')

    epoch_loss=running_loss/len(dataloader_train)
    epoch_acc=correct/total
    loss_history.append(epoch_loss)
    correct_history.append(epoch_acc)
    val_epoch_loss=batch_loss/len(dataloader_valid)
    val_epoch_acc=correct_t/total_t
    val_loss_history.append(val_epoch_loss)
    val_correct_history.append(val_epoch_acc)
      
  return loss_history, val_loss_history, train_acc, val_acc

# %% [markdown]
# # 25 epochs

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = Net()
net.to(device)

loss_history, val_loss_history, train_acc, val_acc = train_model(25, 40)
# Out:
# Epoch 1
#
# Epoch [1/25], Step [0/97], Loss: 1.1130
# Epoch [1/25], Step [40/97], Loss: 0.6504
# Epoch [1/25], Step [80/97], Loss: 0.6435
#
# train-loss: 0.7177, train-acc: 71.2471
# validation loss: 0.7467, validation acc: 74.0676
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/25], Step [0/97], Loss: 0.5501
# Epoch [2/25], Step [40/97], Loss: 0.5242
# Epoch [2/25], Step [80/97], Loss: 0.4001
#
# train-loss: 0.6210, train-acc: 79.2294
# validation loss: 0.5740, validation acc: 83.5015
#
# Improvement-Detected, save-model
# Epoch 3
#
# Epoch [3/25], Step [0/97], Loss: 0.3845
# Epoch [3/25], Step [40/97], Loss: 0.3297
# Epoch [3/25], Step [80/97], Loss: 0.3235
#
# train-loss: 0.5420, train-acc: 84.7208
# validation loss: 0.4943, validation acc: 86.3537
#
# Improvement-Detected, save-model
# Epoch 4
#
# Epoch [4/25], Step [0/97], Loss: 0.3788
# Epoch [4/25], Step [40/97], Loss: 0.3152
# Epoch [4/25], Step [80/97], Loss: 0.3174
#
# train-loss: 0.4898, train-acc: 86.8940
# validation loss: 0.4435, validation acc: 88.8548
#
# Improvement-Detected, save-model
# Epoch 5
#
# Epoch [5/25], Step [0/97], Loss: 0.2926
# Epoch [5/25], Step [40/97], Loss: 0.2790
# Epoch [5/25], Step [80/97], Loss: 0.2317
#
# train-loss: 0.4521, train-acc: 88.3567
# validation loss: 0.4074, validation acc: 89.9079
#
# Improvement-Detected, save-model
# Epoch 6
#
# Epoch [6/25], Step [0/97], Loss: 0.3113
# Epoch [6/25], Step [40/97], Loss: 0.2229
# Epoch [6/25], Step [80/97], Loss: 0.3123
#
# train-loss: 0.4227, train-acc: 89.3597
# validation loss: 0.3816, validation acc: 90.0834
#
# Improvement-Detected, save-model
# Epoch 7
#
# Epoch [7/25], Step [0/97], Loss: 0.2881
# Epoch [7/25], Step [40/97], Loss: 0.2444
# Epoch [7/25], Step [80/97], Loss: 0.3019
#
# train-loss: 0.3994, train-acc: 90.0786
# validation loss: 0.3617, validation acc: 90.9171
#
# Improvement-Detected, save-model
# Epoch 8
#
# Epoch [8/25], Step [0/97], Loss: 0.2164
# Epoch [8/25], Step [40/97], Loss: 0.1795
# Epoch [8/25], Step [80/97], Loss: 0.1931
#
# train-loss: 0.3792, train-acc: 90.9896
# validation loss: 0.3427, validation acc: 92.5845
#
# Improvement-Detected, save-model
# Epoch 9
#
# Epoch [9/25], Step [0/97], Loss: 0.1653
# Epoch [9/25], Step [40/97], Loss: 0.1996
# Epoch [9/25], Step [80/97], Loss: 0.1791
#
# train-loss: 0.3619, train-acc: 91.4828
# validation loss: 0.3268, validation acc: 93.1110
#
# Improvement-Detected, save-model
# Epoch 10
#
# Epoch [10/25], Step [0/97], Loss: 0.2081
# Epoch [10/25], Step [40/97], Loss: 0.2908
# Epoch [10/25], Step [80/97], Loss: 0.1726
#
# train-loss: 0.3466, train-acc: 92.4356
# validation loss: 0.3127, validation acc: 93.3304
#
# Improvement-Detected, save-model
# Epoch 11
#
# Epoch [11/25], Step [0/97], Loss: 0.1706
# Epoch [11/25], Step [40/97], Loss: 0.1752
# Epoch [11/25], Step [80/97], Loss: 0.2354
#
# train-loss: 0.3335, train-acc: 92.7115
# validation loss: 0.3019, validation acc: 93.1549
#
# Epoch 12
#
# Epoch [12/25], Step [0/97], Loss: 0.1482
# Epoch [12/25], Step [40/97], Loss: 0.1614
# Epoch [12/25], Step [80/97], Loss: 0.1621
#
# train-loss: 0.3213, train-acc: 92.8536
# validation loss: 0.2920, validation acc: 92.8477
#
# Improvement-Detected, save-model
# Epoch 13
#
# Epoch [13/25], Step [0/97], Loss: 0.1897
# Epoch [13/25], Step [40/97], Loss: 0.2332
# Epoch [13/25], Step [80/97], Loss: 0.1562
#
# train-loss: 0.3104, train-acc: 93.3216
# validation loss: 0.2894, validation acc: 88.9425
#
# Epoch 14
#
# Epoch [14/25], Step [0/97], Loss: 0.1947
# Epoch [14/25], Step [40/97], Loss: 0.1973
# Epoch [14/25], Step [80/97], Loss: 0.1394
#
# train-loss: 0.3007, train-acc: 93.4303
# validation loss: 0.2811, validation acc: 93.3743
#
# Improvement-Detected, save-model
# Epoch 15
#
# Epoch [15/25], Step [0/97], Loss: 0.1825
# Epoch [15/25], Step [40/97], Loss: 0.1328
# Epoch [15/25], Step [80/97], Loss: 0.0919
#
# train-loss: 0.2914, train-acc: 94.1909
# validation loss: 0.2730, validation acc: 95.1294
#
# Improvement-Detected, save-model
# Epoch 16
#
# Epoch [16/25], Step [0/97], Loss: 0.1991
# Epoch [16/25], Step [40/97], Loss: 0.2040
# Epoch [16/25], Step [80/97], Loss: 0.1373
#
# train-loss: 0.2829, train-acc: 94.4667
# validation loss: 0.2656, validation acc: 94.7345
#
# Improvement-Detected, save-model
# Epoch 17
#
# Epoch [17/25], Step [0/97], Loss: 0.2083
# Epoch [17/25], Step [40/97], Loss: 0.1574
# Epoch [17/25], Step [80/97], Loss: 0.1752
#
# train-loss: 0.2752, train-acc: 94.5169
# validation loss: 0.2606, validation acc: 92.5845
#
# Epoch 18
#
# Epoch [18/25], Step [0/97], Loss: 0.1573
# Epoch [18/25], Step [40/97], Loss: 0.1413
# Epoch [18/25], Step [80/97], Loss: 0.1188
#
# train-loss: 0.2680, train-acc: 94.9348
# validation loss: 0.2542, validation acc: 95.0856
#
# Improvement-Detected, save-model
# Epoch 19
#
# Epoch [19/25], Step [0/97], Loss: 0.1016
# Epoch [19/25], Step [40/97], Loss: 0.0924
# Epoch [19/25], Step [80/97], Loss: 0.1126
#
# train-loss: 0.2609, train-acc: 95.2859
# validation loss: 0.2593, validation acc: 86.0904
#
# Epoch 20
#
# Epoch [20/25], Step [0/97], Loss: 0.1736
# Epoch [20/25], Step [40/97], Loss: 0.1203
# Epoch [20/25], Step [80/97], Loss: 0.1715
#
# train-loss: 0.2548, train-acc: 95.0936
# validation loss: 0.2537, validation acc: 94.7784
#
# Epoch 21
#
# Epoch [21/25], Step [0/97], Loss: 0.1199
# Epoch [21/25], Step [40/97], Loss: 0.0995
# Epoch [21/25], Step [80/97], Loss: 0.1354
#
# train-loss: 0.2488, train-acc: 95.7205
# validation loss: 0.2501, validation acc: 92.6283
#
# Epoch 22
#
# Epoch [22/25], Step [0/97], Loss: 0.1240
# Epoch [22/25], Step [40/97], Loss: 0.1418
# Epoch [22/25], Step [80/97], Loss: 0.1592
#
# train-loss: 0.2430, train-acc: 95.7874
# validation loss: 0.2468, validation acc: 92.4528
#
# Epoch 23
#
# Epoch [23/25], Step [0/97], Loss: 0.1425
# Epoch [23/25], Step [40/97], Loss: 0.1145
# Epoch [23/25], Step [80/97], Loss: 0.1272
#
# train-loss: 0.2378, train-acc: 95.6369
# validation loss: 0.2421, validation acc: 95.0417
#
# Improvement-Detected, save-model
# Epoch 24
#
# Epoch [24/25], Step [0/97], Loss: 0.1319
# Epoch [24/25], Step [40/97], Loss: 0.1389
# Epoch [24/25], Step [80/97], Loss: 0.0762
#
# train-loss: 0.2329, train-acc: 95.5951
# validation loss: 0.2371, validation acc: 95.5682
#
# Improvement-Detected, save-model
# Epoch 25
#
# Epoch [25/25], Step [0/97], Loss: 0.0814
# Epoch [25/25], Step [40/97], Loss: 0.1064
# Epoch [25/25], Step [80/97], Loss: 0.0689
#
# train-loss: 0.2281, train-acc: 96.1133
# validation loss: 0.2325, validation acc: 95.9631
#
# Improvement-Detected, save-model

# %%
plt.plot(loss_history,label='Training Loss')  
plt.plot(val_loss_history,label='Validation Loss')  
plt.legend()  
plt.show()  
plt.plot(train_acc,label='Training accuracy')  
plt.plot(val_acc,label='Validation accuracy')  
plt.legend()  
plt.show()

# %%
total_t=0
correct_t=0
all_preds = []
all_labels = []
with torch.no_grad():
  net.eval()
  for data_t, target_t in (dataloader_test):
      data_t, target_t = data_t.to(device), target_t.to(device)
      outputs_t = net(data_t)
      _,pred_t = torch.max(outputs_t, dim=1)
      correct_t += torch.sum(pred_t==target_t).item()
      total_t += target_t.size(0)
      all_preds.append(pred_t)
      all_labels.append(target_t)
print('Accuracy of the network on the test images: %d %%' % (
    100 * correct_t / total_t))
# Out:
# Accuracy of the network on the test images: 95 %

# %%
plt.figure(figsize=(8,8))
plot_confusion_matrix(all_preds, all_labels, test_dataset.classes)
# Out:
# tensor([[199,  16,   2],
#         [ 16, 595,   1],
#         [  0,   6,  75]])

# %%
print('\n*Classification Report:\n', metrics.classification_report(torch.cat(all_labels, dim=0).detach().cpu().numpy(), torch.cat(all_preds, dim=0).detach().cpu().numpy(), target_names=['COVID', 'Normal', 'Viral Pneumonia']))
# Out:
# *Classification Report:
#                   precision    recall  f1-score   support
#
#           COVID       0.93      0.92      0.92       217
#          Normal       0.96      0.97      0.97       612
# Viral Pneumonia       0.96      0.93      0.94        81
#
#        accuracy                           0.95       910
#       macro avg       0.95      0.94      0.94       910
#    weighted avg       0.95      0.95      0.95       910
